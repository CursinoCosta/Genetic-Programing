# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
Testes = ['r_pop30', 'r_pop50','r_pop100','r_gen50','r_gen100']
# vars : gen, bestFit, worstFit, meanFit, Nrepeats, orgulho, decpcao

rP30 = pd.read_csv('results/r_pop30_mean.csv')
rP50 = pd.read_csv('results/r_pop50_mean.csv')
rP100 = pd.read_csv('results/r_pop100_mean.csv')
rG30 = pd.read_csv('results/r_gen30_mean.csv')
rG50 = pd.read_csv('results/r_gen50_mean.csv')
rG100 = pd.read_csv('results/r_gen100_mean.csv')
dfs = [rP30, rP50, rP100, rG30, rG50, rG100]

# %%
Testes = ['r_pop30', 'r_pop50','r_pop100','r_gen50','r_gen100']
# vars : gen, bestFit, worstFit, meanFit, Nrepeats, orgulho, decpcao

dpP30 = pd.read_csv('results/r_pop30_dp.csv')
dpP50 = pd.read_csv('results/r_pop50_dp.csv')
dpP100 = pd.read_csv('results/r_pop100_dp.csv')
dpG30 = pd.read_csv('results/r_gen30_dp.csv')
dpG50 = pd.read_csv('results/r_gen50_dp.csv')
dpG100 = pd.read_csv('results/r_gen100_dp.csv')
dfs = [dpP30, dpP50, dpP100, dpG30, dpG50, dpG100]

# %%
Testes = ['r_pop30', 'r_pop50','r_pop100','r_gen50','r_gen100']
# vars : gen, bestFit, worstFit, meanFit, Nrepeats, orgulho, decpcao

rProbs = pd.read_csv('results/r_probs_mean.csv')
dpProbs = pd.read_csv('results/r_probs_dp.csv')
rnE = pd.read_csv('results/r_nE_mean.csv')
dpnE = pd.read_csv('results/r_nE_dp.csv')
rT5 = pd.read_csv('results/r_T5_mean.csv')
dpT5 = pd.read_csv('results/r_T5_dp.csv')
rDataT = pd.read_csv('results/r_DataT_mean.csv')
dpDataT = pd.read_csv('results/r_DataT_dp.csv')
rDataW = pd.read_csv('results/r_wineTrain_mean.csv')
dpDataW = pd.read_csv('results/r_wineTrain_dp.csv')
rDataWT = pd.read_csv('results/r_wineTest_mean.csv')
dpDataWT = pd.read_csv('results/r_wineTest_dp.csv')

# %%
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, figsize=(10, 6))
x = rP30['gen']
var = 'bestFit'
ax1.plot(x, rP30[var],label = 'p30', linestyle='-', color='r')
ax1.plot(x, rP50[var],label = 'p50',  linestyle='-', color='g')
ax1.plot(x, rP100[var],label = 'p100', linestyle='-', color='b')


ax1.set_title(var + ' por Geração alterando o popsize')
ax1.legend()
ax1.set_xlabel('Gerações')
ax1.set_ylabel(var)

x = rP30['gen']
var = 'worstFit'
ax2.plot(x, rP30[var],label = 'p30', linestyle='-', color='r')
ax2.plot(x, rP50[var],label = 'p50',  linestyle='-', color='g')
ax2.plot(x, rP100[var],label = 'p100', linestyle='-', color='b')


ax2.set_title(var + ' por Geração alterando o popsize')
ax2.legend()
ax2.set_xlabel('Gerações')
ax2.set_ylabel(var)


x = rP30['gen']
var = 'meanFit'
ax3.plot(x, rP30[var],label = 'p30', linestyle='-', color='r')
ax3.plot(x, rP50[var],label = 'p50',  linestyle='-', color='g')
ax3.plot(x, rP100[var],label = 'p100', linestyle='-', color='b')


ax3.set_title(var + ' por Geração alterando o popsize')
ax3.legend()
ax3.set_xlabel('Gerações')
ax3.set_ylabel(var)

x = rP30['gen']
var = 'Nrepeats'
ax4.plot(x, rP30[var],label = 'p30', linestyle='-', color='r')
ax4.plot(x, [30]*31,label = '30', linestyle='-.', color='lightcoral')
ax4.plot(x, rP50[var],label = 'p50',  linestyle='-', color='g')
ax4.plot(x, [50]*31,label = '50', linestyle='-.', color='lime')
ax4.plot(x, rP100[var],label = 'p100', linestyle='-', color='b')
ax4.plot(x, [100]*31,label = '100', linestyle='-.', color='aqua')


ax4.set_title(var + ' por Geração alterando o popsize')
ax4.legend()
ax4.set_xlabel('Gerações')
ax4.set_ylabel(var)

plt.tight_layout()

# %%
x = rP30['gen']
var1 = 'orgulho'
var2 = 'decepcao'
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(12, 3))
fig.suptitle('Filhos' + ' por Geração alterando o popsize')

ax1.plot(x, rP30[var1],label = 'Orgulho - p30', linestyle='-', color='gold')
ax1.plot(x, rP30[var2],label = 'Decepção - p30', linestyle='-', color='orangered')
ax1.legend()
ax1.set_xlabel('Gerações')
ax1.set_ylabel('Filhos')



ax2.plot(x, rP50[var1],label = 'Orgulho - p50',  linestyle='-', color='gold')
ax2.plot(x, rP50[var2],label = 'Decepção - p50', linestyle='-', color='orangered')
ax2.legend()
ax2.set_xlabel('Gerações')
ax2.set_ylabel('Filhos')


ax3.plot(x, rP100[var1],label = 'Orgulho - p100', linestyle='-', color='gold')
ax3.plot(x, rP100[var2],label = 'Decepção - p100', linestyle='-', color='orangered')
ax3.legend()
ax3.set_xlabel('Gerações')
ax3.set_ylabel('Filhos')

plt.tight_layout()

# %%
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, figsize=(10, 6))

x = rG100['gen']
var = 'bestFit'
ax1.plot(rG30['gen'], rG30[var],label = 'g30', linestyle='-', color='b')
ax1.plot(rG50['gen'], rG50[var],label = 'g50', linestyle='-', color='r')
ax1.plot(x, rG100[var],label = 'g100', linestyle='-', color='g')


ax1.set_title(var + ' por Geração alterando o gensize')
ax1.legend()
ax1.set_xlabel('Gerações')
ax1.set_ylabel(var)

x = rG100['gen']
var = 'worstFit'
ax2.plot(rG30['gen'], rG30[var],label = 'g30', linestyle='-', color='b')
ax2.plot(rG50['gen'], rG50[var],label = 'g50', linestyle='-', color='r')
ax2.plot(x, rG100[var],label = 'g100', linestyle='-', color='g')


ax2.set_title(var + ' por Geração alterando o gensize')
ax2.legend()
ax2.set_xlabel('Gerações')
ax2.set_ylabel(var)


var = 'meanFit'
ax3.plot(rG30['gen'], rG30[var],label = 'g30', linestyle='-', color='b')
ax3.plot(rG50['gen'], rG50[var],label = 'g50', linestyle='-', color='r')
ax3.plot(rG100['gen'], rG100[var],label = 'g100', linestyle='-', color='g')


ax3.set_title(var + ' por Geração alterando o gensize')
ax3.legend()
ax3.set_xlabel('Gerações')
ax3.set_ylabel(var)


var = 'Nrepeats'
ax4.plot(rG30['gen'], rG30[var],label = 'g30', linestyle='-', color='b')
ax4.plot(rG50['gen'], rG50[var],label = 'g50', linestyle='-', color='r')
ax4.plot(rG100['gen'], rG100[var],label = 'g100', linestyle='-', color='g')


ax4.set_title(var + ' por Geração alterando o gensize')
ax4.legend()
ax4.set_xlabel('Gerações')
ax4.set_ylabel(var)
plt.tight_layout()

# %%
x = rP30['gen']
var1 = 'orgulho'
var2 = 'decepcao'
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(12, 3))
fig.suptitle('Filhos' + ' por Geração alterando o gensize')

ax1.plot(rG30['gen'], rG30[var1],label = 'Orgulho - g30', linestyle='-', color='gold')
ax1.plot(rG30['gen'], rG30[var2],label = 'Decepção - g30', linestyle='-', color='orangered')
ax1.legend()
ax1.set_xlabel('Gerações')
ax1.set_ylabel('Filhos')


ax2.plot(rG50['gen'], rG50[var1],label = 'Orgulho - g50', linestyle='-', color='gold')
ax2.plot(rG50['gen'], rG50[var2],label = 'Decepção - g50', linestyle='-', color='orangered')
ax2.legend()
ax2.set_xlabel('Gerações')
ax2.set_ylabel('Filhos')



ax3.plot(rG100['gen'], rG100[var1],label = 'Orgulho - g100', linestyle='-', color='gold')
ax3.plot(rG100['gen'], rG100[var2],label = 'Decepção - g100', linestyle='-', color='orangered')
ax3.legend()
ax3.set_xlabel('Gerações')
ax3.set_ylabel('Filhos')



plt.tight_layout()

# %%
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(12, 3))
teste = 'r_pop30'
x = rP30['gen']
ax1.plot(x, dpP30['meanFit'],label = 'dp da meanFit', linestyle='-', color='r')
ax1.plot(x, rP30['meanFit'],label = 'meanFit',  linestyle='-', color='g')
ax1.plot(x, rP30['bestFit'],label = 'bestFit', linestyle='-', color='b')


ax1.set_title('Comparação DP 30 indv por 30 gerações')
ax1.legend()
ax1.set_xlabel('Gerações')
ax1.set_ylabel('Fit')

teste = 'r_pop50'
x = rP30['gen']
ax2.plot(x, dpP50['meanFit'],label = 'dp da meanFit', linestyle='-', color='r')
ax2.plot(x, rP50['meanFit'],label = 'meanFit',  linestyle='-', color='g')
ax2.plot(x, rP50['bestFit'],label = 'bestFit', linestyle='-', color='b')


ax2.set_title('Comparação DP 50 indv por 30 gerações')
ax2.legend()
ax2.set_xlabel('Gerações')
ax2.set_ylabel('Fit')

teste = 'r_pop100'
x = rP30['gen']
ax3.plot(x, dpP100['meanFit'],label = 'dp da meanFit', linestyle='-', color='r')
ax3.plot(x, rP100['meanFit'],label = 'meanFit',  linestyle='-', color='g')
ax3.plot(x, rP100['bestFit'],label = 'bestFit', linestyle='-', color='b')


ax3.set_title('Comparação DP 100 indv por 30 gerações')
ax3.legend()
ax3.set_xlabel('Gerações')
ax3.set_ylabel('Fit')
plt.tight_layout()

# %%
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(12, 3))
teste = 'r_gen30'
x = rP30['gen']
ax1.plot(x, dpG30['meanFit'],label = 'dp da meanFit', linestyle='-', color='r')
ax1.plot(x, rG30['meanFit'],label = 'meanFit',  linestyle='-', color='g')
ax1.plot(x, rG30['bestFit'],label = 'bestFit', linestyle='-', color='b')

ax1.set_title('Comparação DP 50 indv por 30 gerações')
ax1.legend()
ax1.set_xlabel('Gerações')
ax1.set_ylabel('Fit')

teste = 'r_gen50'
x = rG50['gen']
ax2.plot(x, dpG50['meanFit'],label = 'dp da meanFit', linestyle='-', color='r')
ax2.plot(x, rG50['meanFit'],label = 'meanFit',  linestyle='-', color='g')
ax2.plot(x, rG50['bestFit'],label = 'bestFit', linestyle='-', color='b')

ax2.set_title('Comparação DP 50 indv por 50 gerações')
ax2.legend()
ax2.set_xlabel('Gerações')
ax2.set_ylabel('Fit')


teste = 'r_gen100'
x = rG100['gen']
ax3.plot(x, dpG100['meanFit'],label = 'dp da meanFit', linestyle='-', color='r')
ax3.plot(x, rG100['meanFit'],label = 'meanFit',  linestyle='-', color='g')
ax3.plot(x, rG100['bestFit'],label = 'bestFit', linestyle='-', color='b')


ax3.set_title('Comparação DP 50 indv por 100 gerações')
ax3.legend()
ax3.set_xlabel('Gerações')
ax3.set_ylabel('Fit')
plt.tight_layout()

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 3))
x = rProbs['gen']
var = 'meanFit'
ax1.plot(x, dpProbs[var],label = 'dp meanFit', linestyle='-', color='r')
ax1.plot(x, rProbs['meanFit'],label = 'meanFit',  linestyle='-', color='g')
ax1.plot(x, rProbs['bestFit'],label = 'bestFit', linestyle='-', color='b')

ax1.set_title('Comparação DP por Geração probs')
ax1.legend()
ax1.set_xlabel('Gerações')
ax1.set_ylabel(var)

x = rProbs['gen']
var1 = 'orgulho'
var2 = 'decepcao'

ax2.plot(rProbs['gen'], rProbs[var1],label = 'Orgulho - probs', linestyle='-', color='gold')
ax2.plot(rProbs['gen'], rProbs[var2],label = 'Decepção - probs', linestyle='-', color='orangered')
ax2.set_title('Filhos 50 indv por 30 gerações probs')
ax2.legend()
ax2.set_xlabel('Gerações')
ax2.set_ylabel('Filhos')
plt.tight_layout()

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 3))
x = rnE['gen']
var = 'meanFit'
ax1.plot(x, dpnE[var],label = 'dp meanFit', linestyle='-', color='r')
ax1.plot(x, rnE['meanFit'],label = 'meanFit',  linestyle='-', color='g')
ax1.plot(x, rnE['bestFit'],label = 'bestFit', linestyle='-', color='b')

ax1.set_title('Comparação DP por Geração sem elitismo')
ax1.legend()
ax1.set_xlabel('Gerações')
ax1.set_ylabel(var)

x = rnE['gen']
var1 = 'orgulho'
var2 = 'decepcao'

ax2.plot(rnE['gen'], rnE[var1],label = 'Orgulho - probs', linestyle='-', color='gold')
ax2.plot(rnE['gen'], rnE[var2],label = 'Decepção - probs', linestyle='-', color='orangered')
ax2.set_title('Filhos 50 indv por 30 gerações sem elitismo')
ax2.legend()
ax2.set_xlabel('Gerações')
ax2.set_ylabel('Filhos')
plt.tight_layout()

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 3))
x = rDataT['gen']
var = 'meanFit'
ax1.plot(x, dpDataT[var],label = 'dp meanFit', linestyle='-', color='r')
ax1.plot(x, rDataT['meanFit'],label = 'meanFit',  linestyle='-', color='g')
ax1.plot(x, rDataT['bestFit'],label = 'bestFit', linestyle='-', color='b')
ax1.plot(x, rDataT['worstFit'],label = 'worstFit', linestyle='-', color='y')

ax1.set_title('Comparação DP por Geração Base Teste')
ax1.legend()
ax1.set_xlabel('Gerações')
ax1.set_ylabel(var)

x = rDataT['gen']
var1 = 'orgulho'
var2 = 'decepcao'

ax2.plot(rDataT['gen'], rDataT[var1],label = 'Orgulho - probs', linestyle='-', color='gold')
ax2.plot(rDataT['gen'], rDataT[var2],label = 'Decepção - probs', linestyle='-', color='orangered')
ax2.set_title('Filhos 50 indv por 30 gerações Base Teste')
ax2.legend()
ax2.set_xlabel('Gerações')
ax2.set_ylabel('Filhos')

#add Nrepeats

plt.tight_layout()

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 3))
x = rT5['gen']
var = 'meanFit'
ax1.plot(x, dpT5[var],label = 'dp meanFit', linestyle='-', color='r')
ax1.plot(x, rT5['meanFit'],label = 'meanFit',  linestyle='-', color='g')
ax1.plot(x, rT5['bestFit'],label = 'bestFit', linestyle='-', color='b')
ax1.plot(x, rT5['worstFit'],label = 'worstFit', linestyle='-', color='y')

ax1.set_title('Comparação DP por Geração K=5')
ax1.legend()
ax1.set_xlabel('Gerações')
ax1.set_ylabel(var)

x = rT5['gen']
var1 = 'orgulho'
var2 = 'decepcao'

ax2.plot(rT5['gen'], rT5[var1],label = 'Orgulho - probs', linestyle='-', color='gold')
ax2.plot(rT5['gen'], rT5[var2],label = 'Decepção - probs', linestyle='-', color='orangered')
ax2.set_title('Filhos 50 indv por 30 gerações K=5')
ax2.legend()
ax2.set_xlabel('Gerações')
ax2.set_ylabel('Filhos')

#add Nrepeats

plt.tight_layout()

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 3))
x = rDataW['gen']
var = 'meanFit'
ax1.plot(x, dpDataW[var],label = 'dp meanFit', linestyle='-', color='r')
ax1.plot(x, rDataW['meanFit'],label = 'meanFit',  linestyle='-', color='g')
ax1.plot(x, rDataW['bestFit'],label = 'bestFit', linestyle='-', color='b')
ax1.plot(x, rDataW['worstFit'],label = 'worstFit', linestyle='-', color='y')

ax1.set_title('Comparação DP por Geração Base Wine Treino')
ax1.legend()
ax1.set_xlabel('Gerações')
ax1.set_ylabel(var)

x = rDataW['gen']
var1 = 'orgulho'
var2 = 'decepcao'

ax2.plot(rDataW['gen'], rDataW[var1],label = 'Orgulho - probs', linestyle='-', color='gold')
ax2.plot(rDataW['gen'], rDataW[var2],label = 'Decepção - probs', linestyle='-', color='orangered')
ax2.set_title('Filhos 50 indv por 30 gerações Base Wine Treino')
ax2.legend()
ax2.set_xlabel('Gerações')
ax2.set_ylabel('Filhos')

#add Nrepeats

plt.tight_layout()

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 3))
x = rDataWT['gen']
var = 'meanFit'
ax1.plot(x, dpDataWT[var],label = 'dp meanFit', linestyle='-', color='r')
ax1.plot(x, rDataWT['meanFit'],label = 'meanFit',  linestyle='-', color='g')
ax1.plot(x, rDataWT['bestFit'],label = 'bestFit', linestyle='-', color='b')
ax1.plot(x, rDataWT['worstFit'],label = 'worstFit', linestyle='-', color='y')

ax1.set_title('Comparação DP por Geração Base Wine Teste')
ax1.legend()
ax1.set_xlabel('Gerações')
ax1.set_ylabel(var)

x = rDataWT['gen']
var1 = 'orgulho'
var2 = 'decepcao'

ax2.plot(rDataWT['gen'], rDataWT[var1],label = 'Orgulho - probs', linestyle='-', color='gold')
ax2.plot(rDataWT['gen'], rDataWT[var2],label = 'Decepção - probs', linestyle='-', color='orangered')
ax2.set_title('Filhos 50 indv por 30 gerações Base Wine Teste')
ax2.legend()
ax2.set_xlabel('Gerações')
ax2.set_ylabel('Filhos')

#add Nrepeats

plt.tight_layout()
