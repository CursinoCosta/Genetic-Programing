# %%
import pandas as pd
from anytree import Node, RenderTree
from sklearn.preprocessing import normalize

# %%
data = pd.read_csv('data/breast_cancer_coimbra_train.csv')
datan = normalize(data)
datan = pd.DataFrame(datan, columns=data.columns)
# Out:
#          Age       BMI   Glucose   Insulin      HOMA    Leptin  Adiponectin  \
# 0   0.364902  0.172167  0.713217  0.062639  0.013269  0.116852     0.168518
# 1   0.144222  0.065307  0.275902  0.010723  0.002328  0.040351     0.058159
# 2   0.074969  0.052040  0.142865  0.014393  0.003586  0.038452     0.028333
# 3   0.043798  0.024724  0.072997  0.004491  0.000997  0.010001     0.007893
# 4   0.068847  0.049089  0.186293  0.043939  0.009971  0.033888     0.044191
# ..       ...       ...       ...       ...       ...       ...          ...
# 87  0.071343  0.046587  0.142686  0.007472  0.001659  0.037809     0.010534
# 88  0.201617  0.123835  0.397927  0.030678  0.005675  0.080965     0.095237
# 89  0.067223  0.039818  0.112468  0.039056  0.008381  0.037844     0.008104
# 90  0.153016  0.051469  0.168914  0.009102  0.001908  0.027305     0.019382
# 91  0.155642  0.074027  0.232266  0.025121  0.006011  0.105410     0.008884
#
#     Resistin     MCP.1  Classification
# ...

# %%
def div(a,b):
    if(b==0):
        return 1
    else:
        return a/b

# %%
def derivacao(nterm, num):
    if(nterm == '<start>'):
        if(num%10 == 0):
            return ( '<exp> <op> <exp>')
        if(num%10 == 1):
            return ( '<exp> <op> <exp>')
        if(num%10 == 2):
            return ('<exp> <op> <exp> <op> <exp>')
        if(num%10 == 3):
            return ('<exp> <op> <exp> <op> <exp> <op> <exp>')
        if(num%10 == 4):
            return ( '<exp> <op> <exp> <op> <exp> <op> <exp> <op> <exp>')
        if(num%10 == 5):
            return ( '<exp> <op> <exp> <op> <exp> <op> <exp> <op> <exp> <op> <exp>')
        if(num%10 == 6):
            return ( '<exp> <op> <exp> <op> <exp> <op> <exp> <op> <exp> <op> <exp> <op> <exp>')
        if(num%10 == 7):
            return ( '<exp> <op> <exp> <op> <exp> <op> <exp> <op> <exp> <op> <exp> <op> <exp> <op> <exp>')
        if(num%10 == 8):
            return ('<exp> <op> <exp> <op> <exp> <op> <exp> <op> <exp> <op> <exp> <op> <exp> <op> <exp> <op> <exp>')
        if(num%10 == 9):
            return ('<exp> <op> <exp> <op> <exp> <op> <exp> <op> <exp> <op> <exp> <op> <exp> <op> <exp> <op> <exp> <op> <exp>')
    
    if(nterm == '<exp>'):
        if(num%3 == 0):
            return ('<term> <op> <term>')
        elif(num%3 == 1):
            return ('( <term> <op> <term> )')
        elif(num%3 == 2):
            return ( '<protop> ( <term> , <term> )')
            
    elif(nterm == '<op>'):
        if(num%3 == 0):
            return ( '+')
        elif(num%3 == 1):
            return ('-')
        elif(num%3 == 2):
            return ('*')
        elif(num%3 == 3):
            return ('<protop>')
            
    if(nterm == '<protop>'):
        return ('div')

    if(nterm == '<term>'):
        return (f'x{num%8}')
        
    else:
        return ('t')

# %%
def dividir_binario(numero, tamanho_segmento=5):
    binario = bin(numero)[2:]
    binario = binario.zfill(((len(binario) + tamanho_segmento - 1) // tamanho_segmento) * tamanho_segmento)
    
    segmentos = [binario[i:i + tamanho_segmento] for i in range(0, len(binario), tamanho_segmento)]
    return [int(segmento, 2) for segmento in segmentos]

i = 0

def incrementar():
    global i
    i += 1   
    
def reset():
    global i
    i = 0

def check():
    return i

# %%
def ConstructTree(nums,no = '<start>', pai=None):
    if(check() >= len(nums)):
        reset()
    no = Node(no, parent=pai)
    
    next = derivacao(no.name, nums[i])
    incrementar()
    if(next == 't'):
        return no
    for s in next.split():
        ConstructTree(nums,s,no)
        
    return no
        
        

def ImprimeArvore(raiz):
    for pre, _, node in RenderTree(raiz):
        print(f"{pre}{node.name}")

def armazena_folhas(raiz):
    folhas = []
    for pre, _, n in RenderTree(raiz):
        if not n.children:
            folhas.append(n.name)  
    return folhas

# %%
nums = dividir_binario(16549846546846541654465431232323567569749721554964964246126)
print(nums)
arvore = ConstructTree(nums)
folhas = armazena_folhas(arvore)
' '.join(folhas)
# Out:
# [10, 17, 15, 8, 29, 14, 14, 25, 29, 22, 30, 31, 30, 10, 22, 17, 2, 21, 24, 18, 28, 22, 12, 0, 31, 8, 5, 12, 2, 26, 15, 5, 31, 6, 13, 2, 0, 19, 14]
# '( x6 - x2 ) * x2 - x0 * x2 + x7 - x3 - x7 * div ( x6 , x2 )'
